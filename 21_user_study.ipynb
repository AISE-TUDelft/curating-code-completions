# %% [markdown]
# ## Usage Data Graphs
# - Acceptance Rate per filter;
# - n manual invocations per filter;
# - Acceptance Rate per user over a session; to see whether there are temporal changes

# %%
import os, subprocess, json, pandas as pd, matplotlib.pyplot as plt, datetime as dt
while not os.getcwd().endswith('-analysis'): os.chdir('..')

SERVER_DATA_DIR = 'REDACTED' 
DATA_DIR = os.path.join('..', 'data')

_ = subprocess.run(['rsync', '-avz', f'larisa:{SERVER_DATA_DIR}', DATA_DIR])
DATA_DIR = os.path.join(DATA_DIR, SERVER_DATA_DIR.split('/')[-1])
# Out:
# Authenticated to larisa.ewi.tudelft.nl ([130.161.252.12]:22) using "publickey".
# receiving file list ... done
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/003767253b9442139369be188d8db0c0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0040864f5bad41bfba7a15ee757c1121.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/01310138a9a34f7685f9bcd28ee194de.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/017ef7fc38dd47c3be0ec5e44b8f872b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/01c6efe66ef041ab96265ce125769185.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/021cdd7f4598414cb3c7cb29c64c1255.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0230bef96e7e4b23a046edc5b6ea0420.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0233c9817b504b909b88c617c39b0af0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/02bcf63d3bed4ebca613b740784556d7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/02c947732aef4d86b115a04282110d84.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0314670d13b949719b14ea4a31bea4a9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/03535e7bbcc3472b987e2d9daa76545a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/03aaf383b8d247c9a74c18f994fbc9c7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/03bd3946028b413c8f145c15b9b14740.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/03c7b4add33b4bbebed382d959192233.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/04775258c14e469b8ea7555d09107855.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/04a42ccb3da64424846c97fa82043352.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/04b2f07a50db4c92a6c03e0cfcda88f1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/051c2c798dec4c78b0929d057e4b1a15.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/052503e4c00b449c9410e43a6a067e80.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0540737ee0fb446da47e6c6cdebf8de0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/060140768af0489db426169d6a691d22.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0612d6f549e745e5a01981fef9b7ca86.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/06925c0746e746578c16bd0b326d6cd1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/076768ce27ba471ea4879e7a9315a730.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0767e6d4310146b383bb1724079671b3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0771462eb5c84ebdb955a49b2ce1b1eb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0804dce35abf4269b16e13ca2cc95600.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0808ccdf7db1472c9b141f78a9878ec8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/087e138f682a43f5a6ec911668309be7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0892968361a540a486686033a4413b7d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/08bcf4a53a364282ae3e52fd4e411356.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/08e22ba8c1484180be26b5db9a4b6f0e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0919fc38f2774584993375267c8c725d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/092a142c95e94a0db4a774003a5a6ede.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0940b928c8ba44918ced3c266367fb64.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0a5f778a1e2e43c9aa6814fc7ae43d4f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0a682402af224666a18ebd684b53a123.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0a8e2e41bcae46bbb99c3bf11c1ad521.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0a9d13344e4f48659f1a92afe4632d43.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0af9dc012a0f46c8bbffbd68458210c5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0b401ea1057c406fb6a9c81467dc522b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0b5806998d554e928213bfbea9e73f58.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0b957e27d2954849bd7ce95a8c318227.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0b98aa74b26d44cbb4f8f48e154aac43.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0c47ad11a12746a2a8dfbfc44c6e4bce.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0c588611c77e49f283737a678a8ae4c4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0d05ff111e3a4ec0998d7182976c17fc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0d0d6cdfc1f74d07bf298a5dc5eb4372.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0d31a9598d344cf4bbec139b9a208f32.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0d6ba8115b5542c1bf4f4fd90fa292c9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0dc6971b9a6a4eb1befea74f7a218b7f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0dd056c828284e90a9037779da8333a8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0dd0d18fb2974ad394ebc1e45192160a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0e456487b0624190bfa5a37e002703a8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0e5827b7691444fc8e57e7fd48594b0b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0e634134b9f84e95a9eadcdbde2d04e2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0e7649ebe2e84a768f8b04cf021a9ccb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0eb5ab0ee28245fda7e3dbca7461eabd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0f7e76e71f2a4ccfa576e50b99b4ae4f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0fb8d95f15e0466a927da690a1be8d8f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/0ff62ae5802445809c3f2202fea31ba2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/10087d739d674ee0b5bfc41e08c475b2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/114821909c1642539c693de103d1daad.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/12153c00b73a41f9966b3e8fcfad33e8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/127fe708784f46cbaddf8e14213395f1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/12fe2609baf843f79c3621a8776a9144.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/13bda934dbfc487abe6dcf55f993d27d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/147dfc93ebdd4ec7b6b83fbba1a7e48e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/148090363a1b4247bc002221280614d7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/14d5d44f59084ed8a7bc9b1b64a10a36.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/159419299d2e41b3b11209c0bee3e821.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/164c3e9956ab4df9903936b48d88582b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/16976369c26a42f9b1907eece5417ef5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1767227e25c649da8803b707a110a319.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/178627a2ea0d494a903d1df7d90408c0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/17c17ff88cfe4430971808df07436f12.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/17c3d25758ac4bfe91f93f39a21ecfc0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/17e0e443fd774dee96382507760f2aaf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/17e3ddbaf2b844a090bbcef975658b4f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1826ca74df2c4a3fbd513bc45bc449f2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/18a06d32013c4a9993df5dbdad828428.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/18f41f49071f4097835ed6bae0e6681c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/18f47cdeec2c48d88c4dcb801e2bdfe1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1911de91813e4f36bfa1ddaeabecf48c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/19950e0167c34922864576db5207f58e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1a05593b241641e6935d820a7f5ff18f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1a16d486a7d04ae2950e220dc3c4c8b2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1a2e96ede5a24f4bb78b439ba0a54dd5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1a557489e1b64dd7abdfe9e2e6e4a436.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1ad00c1f03084fe5a6ac4db10947038b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1af7e39da2ad4fe98c515849feffc5f9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1b0211ab49724de090daa50ba788aab8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1b38edae0240496d989578c007523489.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1b6cc4784ecb4af1bb4895c5a3137cab.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1b7810a3f4ba492bb127a74d6be2694b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1bde908b97f94f64b6fa3581f7a81a2b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1d1322d6ee664cd5abd2e847a6d3a989.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1d32d94271d14e0d81adc2ce520c24a8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1e7a995a0ecc45a4bc8a80743c7decea.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1e7b3e593d514805ad141eec7b652a33.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1eb27571f4be4fa6a8c0300776754408.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1eecd8039a854529ae5c24b984a7e06d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1fbefa9117e642ec847945ccb6ceac98.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/1fdd6821608646d89830b9c173466694.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2014cbbb57c94ddfa99f3bb2407d6ee2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2046add980b04009b8658cfb63f464fc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/20b6cb48e9554c26bce1c61eb9d6c599.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/216be9a6e32e42c9bfa0fd6f4dd9f07d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/22d9d0839a864f90890ae4e97218732f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/22f505b9ca7244ffbbaa14c8548eaab7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2331524776434ffcbfc4d908d95fa5de.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2492a47558ed4509aadc47bef1c02288.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/24cda3791904423cbb52b9067d7de738.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/24dee67b01ac474c8d8809a6cac7d771.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/25a1410b3a4f47cf8de908fb4453918e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/25d03d6c296641abb3d28c58bc4cc477.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/25fd48cc95d948ef82691a7e8c86aa32.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/26c7e277d2cd45beb33f401bc7ff35d0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2700ef8f79614eb686c97af3782665d4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/270509ec1b3c4fc38adcc91fc11fa4da.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/27198b3ab15f46e78e3ece80ea93a816.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/271b7531050e40b1b7e5c528a4c574a9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/278dd70fc07a420eb47ef249d1e81a9c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/281c26ca780d4951b73eb1f6da165ffe.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/28293dedbf99457086035bd9e08710af.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/285715d77ef94083ad22f5665c551426.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/286e7613bb7048339b4d0df0d701c8bc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/287c261d521c4e23b3385f6c9b0c5ad2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/28e9c8bdfd8149b6ba1acc8af39df92a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/28f0faf06dff4672a9ba615362cef2bc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2937ddebe4a540cd860c92d5d803ffe2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2a1ee6adf2e845838abe9369c7d358e1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2a3c5bf5fda64bd0830441facc4fe345.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2a3feb43dd23440293641219240b94d4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2a5cc0fbdd2844319e802bf7d22d9206.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2a73ab62949e4a448e0a309571361ba5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2ab62408895c47878c84ec6b4efb9fd4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2ae95b6678fd4aaebd98d42f3f373aed.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2b15420efea946b9b1a88b941e2bfae0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2b291bb5da3c47feaee8362e0fad6eec.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2b2e8d4ae4af4f9490b89e1a12892056.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2b7341ca20a445849d3a9abb31be40e7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2c66e2b3a8a44780a463c52bcd5f46e6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2d3d7accfd0e41398b0f5a6c75d17542.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2d5d5e09bace4e6885062149d3815e1e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2d8ca3b46c20423a88bf37b736fab9d5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2e26b7bfdf00405a97378b40a23e616c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2e724c0a3a914d749905d218440d3423.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2eddfd5292764b999a82fa29a557093a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2fa6cb47fd90479dae7b4c60e4c5397b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/2feae1e5328646edb08ac84a4ad12953.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3085b3096d1949e7abda5df985ab51eb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/30ae4de125874b6f9639fbed56466bd5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/30b2a1bb6dc8434896c1be1b255253bc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/30d5ff1b07f84601af95532329db47e7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/314898f537e64141bad020009ac04240.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/317e425728ec4bafa27f7dbebabc7f34.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3218fd07f5874daa8101eeb1c9a4c659.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/335acf3298424127a114c38096d76c23.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/34645b30e76740eb82f6023383d525a7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/349fe3f83f384b38a6b5a8b4e2833dc1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/350497db65754f94b11f4a54d499db5e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/350b879dec7e4e8ea2670d07a97de4f9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/356b4f8557994befa0052bcb2d1bca97.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/359b8cfb270346d8901a510f8a3f07aa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/35a24eba6de04f018e402650d70e22a1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/35a9ebbc423b4c77a156392bdf5a8d4a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/35b4574c6fb242a1909b3a0171255190.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/35d6282240dd4cda878317aabed780d2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3619eaa10ed84914b0a4860b2ba97e8c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/362d13bd3102466ab40d9329c21fbdcf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/364f943f41ed4f0cae4ec9073482cb3e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/36584de056bc4691b8a9b8124ae4fc4d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3693f3a6008b4699aab0b8d3859e079a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/369bb104dcbc48bdb3b250968fb695f3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/36f641af398c4f80a84419c2b520bb5c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/371e08d0fa114c64a7102502db596dfa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3750fea92c324a9596c68894d6c79027.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3763c96fce8643c0b0e462c623f9af1f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3779e944ba114819aa720a6c4b03e53b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/381099e697c84f5d85e8009bb9fae9eb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3822286fc23f42ed9e1157c6bad9dcdf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3846be6b3f654249bf8d861a7ed07369.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/38aec09bada24cada8eea084a39f5d54.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/38bc93d4026343ffad2f462b2839d5ea.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/390a651c903e43a08a1df15b40262e0b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/391ab95499614f299bcfb398ab9c4d94.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/391be92ed0c64e6f9b9a6b81f5d5feed.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/39f16b279e974924bddad25286c43cdf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/39fcad7cde75498287f136d6b74e4370.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3a1b0a6140db4ee085301dc1ea112924.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3a574dd30ed04c65afa02947a966645c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3ae10b221c7d4d61a3138805184a1d25.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3bf8115ace3a425da7393e03698ee746.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3c23aea002cd4177ab3f09cf555b94b9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3c29532d1e2a493c86dc098344346342.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3c7a173651824eb9a4417ccb216d22d8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3c7e8690aec04289894c3bea206177d5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3c9b58c6fc0e4c35bec3f2373c7902bf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3d501ff2a4b34218a113d2672d8ebcf1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3d72c182412746779e86937ce4578f24.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3d7656b075874313b0540a4896598ab6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3e740f360eac4f72a6af12b8b3a103cb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3e7e0cd7e12d4ef7af387280e14677b8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3e82e4b4cb4844838fbe8c01432e742d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3e9b3b76d0f74be9b1f471ed085825d3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/3fb8ff42d67e49fea1f9489c82db21bc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/40850f8c965441a293f03583fca36786.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4127f3057d48484fab5bdf2c53e59a7f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4130028e94a948aabc3df14433d3c1fa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/42200daa772f4beb8fe92a161b12f998.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/43b4d255bd4c47238aa4a160fce440da.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/43c84597b1844818ab51eace1ac49b27.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/442710a9cc794205bc9ccd2413d6d763.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/448526c766b04c65855ceb61ccf13069.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/44f0f08cbbd94d5e96acf488486e28ca.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4522a75dedfe44f5a34ac7dc4c4abefb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4544a7c6f7a0488688ab5d87b809eb29.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/45d42fd301f34dc6bee867a09c6a9074.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4623460808b743919a2a570a0d2f2c70.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/46246d3604af4e79a7d0b2b4aa8e9c85.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/46bebbebe7dd4ce9b194e5cdae2daf8a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/46c6e47521944062a61b14ee62718a45.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4756d5d7172e4190a49c1db096cf1a87.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/47785f5df9754d78a6d43014ff413bae.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/484ebf6933634fc7a54ec186435c1116.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/48925514d2b9408d99037867864adb90.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/48cabcbd0cc04ea5b3d01a13e3521a2a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/48f8dfbd18ac47b9ae4c1b3ae04caed0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/492905663df04ad5acffa5dcfa7ac19c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/494aff8a1bac4c7b9ebe78b865c507d8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/49edda2485be4a26ac041ec223877d91.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/49f14bc8596049eb85df80525e9620fc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4a0a4ee0c3fc4a7eac862a9510390e1f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4a2df1084b3d41eb987c15115478e498.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4a666ca40fd84d739003ed28bc87865e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4a6fd8b50a5344f8b271c733b0ae2d58.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4aafa66f192048a580c4961406e18249.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4ae08341c7d34825843527e74b430b65.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4b7584a9a4fa4c7f8a4c70c7a6f7b324.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4c2ef7fed7374ac8a0a0cdcec3e8e520.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4c527a85458f46fb9f861547c3f64c6d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4c717fc122a546599c121d219f946b06.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4c9f503adde543d9a217d3f00ec99334.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4ce732aac02e45e4b11d1889186530ae.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4cf28055ff584c95b29dfc0c786ccb48.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4d0f90bdd5994e7387d3712b7a068c40.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4e15ddbb09b549689e2ea36b2de8d69c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4e326fc1d3c648b1a8a4f6220de4f94b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4f731fe01cac4ad19da93326579f0aeb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/4f7fd846753a437ea1302f1b13c383fb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/503a4885c8694d8284083857358e64be.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/515fb737763249ebb4ebe1fee385eac0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/51fd9507a50046e3a019d8a776ab0efb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/520c1096df9c4b5bb3b4a3acbf43bde3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5275364e5bd94f3e8736edcb1fad554f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/52a20e28800f47d6a8e14f7c17e36acc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5353cf45c4ea4104802bbffffa128235.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/536e084306de46fe8d1311ee16fca335.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5370778226bc474b827996c4d2c15ae6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5396a97a6eab42938fadc2f759332af3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/539700ab26e84c0697e32ad556d492ec.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/53e52cb8cec443a4a4946c31cfb94117.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/54216b7ce59f4b31867d0c1478f5d067.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5477c267ae3a400b8450ec1aae2499cf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5512281c7684486b937eb398ca811651.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/558058dcda1d4494b152a3224d621710.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/55feeaf0aa8c4a2c86752f69dc8c8211.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/569b2c3ec7734532a7fce5e4a0b3158c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/56fba583432d4b8790d33a9ca47fa7b5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5809888866804cc1ac03f7e7b64c067e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/583a20dd9a054be29f7ea57eae4ccc05.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/58d53396ce8644969c34e59fdb8a32d3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/58f169451d824693bfdfc92271d83cb0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/599fe04173f5462388c448a9d60864a7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/59a571e199024958baa321044c05f921.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5a192565d8bf4b4597011f17f711a844.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5a72c670e5d842b88928695796e24835.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5ad5ad2346404f6c90c4c73008540201.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5b708809dbaf43fcbc64fd6337b9f4cd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5b994d2517b846b595ceaf3cc522154e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5bcc6499108942d7b48855a0e09a13f5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5bee9fa98297498194e98e31d7631ce0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5e53c648128c49128d91a7078eca11b3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5ecb09ca49f14041814eba302f16dd18.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5edf1480cf894229a01b45df82e0fe33.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5f443b65b2d9430798798ededbfabae6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5f6dc5f3a608426899eca6002c0ada15.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5fce03e9208c4b4bb35c1a0d68734010.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/5fea8bb2a9424bfa9b38dc2f355c6832.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/601ad9160e5344dbbb48dacc740d566a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/605212f4da424b818f91a5a6cf52e392.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/606aaf8ce1964ae18613b750816b3d96.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/60cd30e3e6354d9088c678398f8d54d9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/60e8ab20fd334e0bb69e2bdb069a9f9a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/616c4623941b4d9fabfe83ff0a699675.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/61f5d1d9d95243e2a92c2d3b881b69a5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/624402c2b9fd47239a8f5ebdba3c958d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/633104cef272430294717bbc7385c230.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6427e09e2ac64aeb9257543c8c61a5a1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/649099df48e442dbb2c52796a2d68cb7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/64ca80fdb9234288a0d9c7606068ecf5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/65942eecb09f451585cd3c95e8618841.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/65cc2451d3984764b958f2ae2c7437f4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/65cee05bc7324d3b813431983fcf78b9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/66269a4163ee4208b8bf2f9a4012d96c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/667d9588771e4356ba0be54f1a7b6e1f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/66f110d1e5bc4a76821c38b292e1a8c7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6728faf4f66b476897f5a9656b2a2bdf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/675c17fb80f548ca8e697869c081413b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/676a50c74a03470a90ef4b7e48390c51.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/67b6ff9b8e524db383517dec18371f59.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/67bd6e258d2b4f5599640b09d4cc4371.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/67f15d501d104d38aafd0b907dc9dd31.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/67fd50bfa9464a1080b84d764f3a4f8f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/68ad65a8cbb24752a990b07c9c2f339e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/68b9fd7d709f41769eb1361510042c94.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/68efc872f547402fa5b63e9ad141722f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/690e67e5a37e4207baab429ed5a626d2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/69918b6226c64793a67d04d2fcf793da.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/69b14a2643834a00bc19d41c36e2af89.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/69cb037cb7bf424eb9a69ca5a6351345.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/69da319106314d05aeffabaeaa3f37ce.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/69f04858df824ccfa724e0a0e5347a16.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6a6ed2190c3d461b9ba42993265ebaf3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6ad2cfd5388b48b68d662454cbcaaab6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6af4beba8e6a46468531071d2ce236d8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6b307c48705c4166bc2afdbcbae26a98.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6b34f254c9a24ce7a3bf407b67c5d6d9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6c3001d7fe414d0ab5101a23cb1b92f2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6c5b953f822d4579bfecc70f092752b1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6c77c2acb1f544a088cb5d2af7aed6b7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6cb495a846a04bc68b8f7d0ffe364e61.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6cd4ac63defa4cffb306483e60e196a1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6cf6ee1b6a17430eb18a41b809153c1d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6d08454082b245a9b9b5df9dbfe021cb.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6d332654815a4c81b10e68c7b5a79de0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6d335cfd74c44a6fbf7cea4e2196ef7c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6d35c20976034655927c9b9e5629432b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6ddec4fd10524861b07c7b7465ecb175.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6de4dca7e6c249d094669ac952334112.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6e08cce91bbe4a3a92333550a7b59433.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6e3341bd6cba4a87aaaff5c618a21697.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6e427c79ee3c42b6a94da0e82579f643.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6e87ceb3e5a34348923144b9a29dafc1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6eaeca6e79da4013bdbc44f4e4aaeba3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6f29ae2250fc4630b284d6be52f27704.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6f2a363b429d41fba9265fa5208d8450.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6fe381643bf84be69bf2dc55a41cab55.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/6ff7927736e4479dbc8a6cdb57dec4ef.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7058b5afb1a948ee9c0f162daf8f1dc6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/705bfb79f79e453286e78ea9e4ca351f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/707dbb8626354674b1952776eaa9f772.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/70b0e19deafc41258681dd6d7da30856.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/70b176822a9f4058a263746dc16bc076.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/70d0bdf97eef4974ab0732b0d0dd191c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/70d7d848a75540de90cb00df35ebaf5d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7176b6c8dbac4d4db2550e0f6cb3296c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7198019231a947a0a422b05a3fb34010.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/71c0fdaba6594b98bf878fc59bc20018.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/72974d8316d74c17bd7558974ea4e3d2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/72f92a3734d44156933b9cca0bd5ffda.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/73d133b7f334415180292c1e50a1cef8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/73dba3fe95fb4ffa83ec1f3fbe354e49.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/74d42bed0f684ac0978d0f0ce86ac024.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/74e0e0cb07584201a8d3e4018c2177b6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7544bb9fee104f628e416004b433ee08.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/758e1c1966e54aff996976a3c997c6bf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/75c92e113f20453f8943b28d40ec22b3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7711f174861544ab9eac1cce4d8934fc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/771460c0e23848eda24b730184a89084.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/772fd2ce4fb7460990d5ffa6e88dc363.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/77c93f1cfe51473fb846327fd5b094f0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/77ea01dd4f104920b755e9b9f4b18cc5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/78682d7b30a348ca81e42d745060aba1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/78cbfc8dd375448d86f46f3dc1e57797.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/792e4f8ae7ae46e6a94e37527b4d188d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/793465925c6e4a9dadd367ecd4bc174e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/793dc7f1618447bebf50eacc57a8dad3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7980d5ae5ac44cb894a260e4fcce2e53.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/79aba4c620b84d8cba12b8db6285e0af.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/79d14d00bad3489fa304cdd32b3a35f4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7a132b560ae9433eb2df3695c0380219.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7a41c612ffe241b09d30c2a89a4375ae.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7a833590218d49dcb6c34c85c2b33e63.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7b235c01d5514aabbf095ef9ccb727b4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7b8c9aaf103d47e0be09be57f470ae8f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7bd2949b0c1943a7a15afb0905c3de8d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7bdac10bfb3e45c28c1d025383001797.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7c19c7eaf5cd4e63ac38e303241c56c9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7c42bbfdfa254b4288e3a41c80ebb392.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7cabd240c2c8454da710211b3417dda9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7cef4b78f9a34a22b90834538384448e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7d56702349004e2295e51f4f81497ab9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7dabbc8f85b84cb7bc55dbf749d8b4e8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7db022be4c4e4d6287dfd6b28e94f107.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7dc5471ae9034b8393b67c1312510ecf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7e88b5d0a18347848ae9f029710fbe96.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7f8ff1130628427598967fa1546db8ac.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7fbab174dda9465a90244ecb774f4f84.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7fbdafc6408647ef9f7cb3d5a59dad32.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7fc4c174f09643569fa34a6c359f12d2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7fd6b065b0164cebae181d964ae83e04.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/7ff9d3b8c65b4ba9b95f72f3a846227b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/80000e15278b4af6a4f3e71bc10c0c41.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8012401142634295b8b265d58019809b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/80213996062f4ee8b343041b22671659.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/802d84b31ff54454b716d0372af38b3d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/80602a9f81524f91b5c464b8b84b92bd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/80987b6088af4f81b09ad69a202e63dd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8177f8ee61994981b8782fc9a209e9d7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/825da9312d4d42b59a78b76490990079.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8260d1b047e5440b98fed7105bd367b1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/82c97f445961405ea42413fd2eaae6b3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/82c9d2c23b9d41bda89629c579251d4b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/82faafa2d61f426eb9c165db565e5e37.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/83584c2541c046ea9a65ea5ee7d75e7f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/83d93ea580d949db838b3ace388c5381.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/85426879c8e945ed93866973b58b1088.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8562cc6b1aa7479c80792ec5415ae24d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/859d3f44344f416a88f9c98dd493eaa2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/85d6cd9b29e046878b13785c0dcedef6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/85ea41cdcb424070be03d754d119a50e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/85f3603b32764b5b8acfedaf7727a0d4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/86886076a2fa474c91ebe04e93516043.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/86e07a2fac3f4e439b2164b0a2b243a2.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/86e69ad961c74a6b87517a6f2c5b996c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/873f5f103b04451d92c66d6bd2fba590.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/87bc37d1cf6944b98388102755b93c7f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/886946bcdd374b639686f3b2e026079e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/88a98c562e934b6bbdf523359a4c69e4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/88e4147027734d91ab33dda5012d2bd6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/891b9094e3c04603867e766003fd00c0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8947fa4da2b54d889c44f47e46453528.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/89f055aac935410ebb442569c80234b3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8a28e0386be04c08a5897221a5521cb0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8a854fd14cd644b8ada536805bbd8b4c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8ab33401b56641c196aa8c41ea3824ae.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8abf6f290fc14c4d8fbdb0f4d91c63fa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8ac3c0ff2e1a45b79a447a5f391b02a7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8adee4c147ae4aa28c3ee11fc12314a1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8b35af0b38e447cdbbe4634282313fad.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8b5bdc80158c448193fc96e3e9ef3bea.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8ba949eb0b794adfbbc53cb5d614d7ce.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8bbea31113ff4e6784a15ea36f5ea7c9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8c1c4da9df2040a18d5ace463a3a474a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8c43581efccf45b5bc1419bec4e61c47.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8c85cfae487f4b9c83890dabbc03f32f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8d5137921e9e40c0b7e262b5d68e4e41.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8dc6380600314576a879e116b7a5e8ec.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8dea63191746419894fbd4ee22a3073a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8e0dd29902644c9aa1273da6c2c46c33.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8e735290578d4638ad05c1652db2c25d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8f358b91f7914492b5f7c289abc14848.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8f4e449ea06040689ca97438c643219d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/8f9a98cb714041219e656c84703a4b61.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/917446b798ab4607830f2d08bfe2f501.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/91d518e992024b4799be163d55b2083b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/930b0670f1234de8bb353cac06a766c7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/941caab1cfc34d8dac9f04e232188212.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9499cc42c76440bfa8cda595c623e688.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/94a1765182ec4889bba1cdf6374ac4c5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/957430a8211e45d59f93ce6ead6f3710.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/96173e13fec542b885d20074b80bac61.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/962be57713e94f929cac0905cfcbbedd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9631830e37c44207bafd00d948d346bf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9684512a830947b19e513d530f83d2e7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/96a6cc48d5a540919bca97ab6cdb6d90.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/971bb26801364365a1fa91c92b3e703f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/97895e0a502f43269618d23e74992baf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/97a91454574844fa9423bd328074643c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/97b89b3713864a0f8b83069fb64fa0dd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9867c07aa317472da0e9ef4e8dfdf727.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9885ce26441c4ec29be91684be53934f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9890913fe8634ed79e80c6b6a033f2f3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9897258bf8da4f7aa6cf9e1680a426f6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9944674bbcc44c7f88c82a72e04942a8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/999e322581c542dd8e1155dabfc5eb26.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/99d2f52e141e4f3fa4df1c3ea98a523c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9a3a47147dba4a20ad84ddec958bbdd4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9a95a73f534044058a441a2fcd97a487.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9b0d42e7395e41e78c83f69e0c458ef1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9c2e1606ca8e4e1b8418ef290c3048b6.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9c9edec7beba4baea288ec5c82412f89.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9cdf4fd3580f40388923fc543b742121.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9d625bf019954c26a7fefe9452fe4bfa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9dcb2d899b0743bf87a33468f4e9eced.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9de88a1f780f42beb47318007df6cd43.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9ec753c95c2a40a3add41516da39a69b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9f39470b5251441eb4d49985345aa1c4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9f4317c96d7a4ae5ac4e6fc5133dd227.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/9f8960ea1d964929967c454f772a03fe.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a04ba07469414c2ab91b22b725a20415.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a0d3e678f93a44f3b44292ec19d9f6e4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a20e3729d308441ab54a404f863b988e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a29f540d29aa4d1993c420fafbe471f3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a2c6b850a81d413cb456a89d2616590f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a2e0773b212d4d47a2ea39303cd8e7ca.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a3161a3d9c974425a9bc08a3b0641648.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a3d86b46eded4a01b2c66abf6b2b65aa.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a3dfc1726b764ca5ad4cd95663336c77.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a4b41a5d1d974d8c9874ca6410e6ea42.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a549ce40c3f444a58ff95add4a322e30.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a59edf7c74ff457da25c37275547b4f5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a5a79b266831427fb581bc6137e70aac.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a5f6a8afee794be8b4e893915727190c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a653c63624054cfab108400b919cb2ff.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a65683181ceb4ba790b19904c28b5184.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a675c209e3934f7d97289aae7fd57551.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a678bb6d8cd64a078c0259176ece89ca.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a6a027a6bbc64268a2b48fbb7f850628.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a7224d1eb9af46ba9c282dd058e7aad3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a74c3357e2714bd7b6c8f3371cbdf717.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a7d359c9fa1044059a86c7c0d6d97fbc.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a7da979a02ed4724a38b479e8f64fb26.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a7eea5996f404288bfebfd9a4d1202ca.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a8a9f099225d47288eda2fd5af5314cf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/a9e7ae6289434fe4b5967270c6433248.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/aa7bc06a12d444a79c063a5ab1e135ce.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/aa7f43ab9220469ab5fb46a29e10c7b1.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/aac6dce698364d32806f1bb387c15ef8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ab2281de299b4adab5874a1aeb009c86.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ab3d817dcc1c447aa9cbf7428db74cfe.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/abc86b10ea2e4139a363ae3d08f89156.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ac6fabe54a4f4bd5ac6b3d46df403274.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ac7d4c9999b447f49ab1b3a7fd9b3eda.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ac94403bb1874822813474debbc7e23e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/acdc56728c0b434681a5446de062d23d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ad771373743545c7b10c1ac05b9383a5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ade5643b6dfc492b9c1667cf2d34d51b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ae101bcdc2ec4be6ab9ce6d03a8b8927.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ae2d198b593e46deb33219c4c5f4c7c4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/af67c11e28d24a10addd5ad2a6ba6b2b.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/af6a4811db7b4203b923051957416417.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/af6ebe166f7b4f7499cc8ce9f466b65a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/afe802658a6845db9545502015b1ccf9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b056549f10b24bdbbe43d0ab3d2662e4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b0eb0965ffa544b3aa744c54d540fc57.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b165ca83532b4c67900f89cf80495e55.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b19023ae133c40fcbe01dffd30f59098.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b1a377b760044b89ba16d92fbee94e53.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b1ca4eeaf153482abee11c7a32b2ae1a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b1cfb04f80df497795914fdda7618619.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b22a2299cd5f45a2844fe2a3ce22f16c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b251caf8f3e847b185a9a432a9bd3438.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b29c803e209b41628223080f79e35179.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b2c511b313b1484f82dcd5491414d5d5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b2d4be063ee14563b62af0e0ebacc402.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b307b3e3e37045a1a83dbb2765f90dff.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b30b8d77b65d41b5ba0aadbf9eaab169.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b38e91a4a09d49b7b798af60f09b208d.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b41395fb781444038c106273ae61cdc9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b46d5061519946539c5d9a1950fc1df4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b485fe841800438aac012631f8da17bf.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b4d6bd00ed3e40b0be1a0239e143517e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b5aeb097c7c547d7988cd362e6172cc8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b60c96b3477c4f0dab43c848d93c53a5.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b60fef4a8ac9472e9890126704001342.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b613b619a4374eb39c2e7ea96f1e31c0.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b6870b57d14447e4af88887eb2be2bcd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b68d0cb2de9e4df8aef94e169b4d9c29.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b6c0419cdd9847dda7ce9420aa8a738c.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b75634763932433c9b57cfa7fda7056e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b8096394faa64c97b424bc4c4d84d54e.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b80b6fbbce9b4a12949158f80b6ac815.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b89f1805eca342cca61b328f8eecfbc4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b8a86d2bf6454398991acdfe69ba3a6a.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/b9aead0633dc4f59a397f4c29cfe0086.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ba0435c3f722409b8a60d39967822d15.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/ba6b981a2bf5490bafba9ee5fe61741f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bad00547e6794165805a654557e13b15.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bafe88bbae2047569854d5f4df9c1cf3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bcac4b11dd344f6b8f2ab095ce812a30.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bce33ba6e31c40ada9db150a5dc2c396.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bd06ea692ce54a47a5e95f1668666859.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bdbc0c57a77b412ab78eb66f88f71ecd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bdf5ab530d2142358a9630477f948f1f.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bdfb532af23a46d383a1b85571039cbd.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/be011dd8181c4807af91e65884a443f9.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bee9da59cc574d13b60131ce546d2386.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bef9f2dcc034469b95f392b4b62daae8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bf2838d8f21f4f0fafd58462d026a1d8.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bf2f60efca054418b2d8def3d57830f4.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/bff6289be5ba4797817e381694b5e5c3.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/c03ade9b27ad4b4f987ce1431f2d6842.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/c06c42c4204b45f3a05d48f49f610052.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/c110e6d452a64d069d7ac50985ff3345.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/c13276c075894c3dba00836563586dc7.json
# data_aral/0787982c3ee69ffbf34a19d65a92a70f/c1372d77388f4cadb9d4d09dec818d4a.json
# ...
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cd919c39ff774234a9fbcf306a8a6996.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cda25258ee83437293c020407747688e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cdab383130d84c73857c99d1e9950412.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cdc29781c9dc405a986ac8c29640c331.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cdd38a3b8f684a0892c25b1eb15205b5.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cdd7b03cea584121ab1306c0eb6c452b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ceb4262054814075abc7a3ce5e2f675e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cef31e8432194ea1ab6af70714cc2c62.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cf3bae7f806140f7890db404e81edd21.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cf558c31aa5047e9afaeea5c5920212b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cf57712594bd47a8a0ef74d78fa9eaf4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cfad344c76cf438fa1e8e65557512d08.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/cfddb806f2704949b09b2a00468e575f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d0601633d6fa42bfa9ac663959734eb9.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d0791e576c6746d3810c15fc61162ee7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d088c43a4b054c25baf060a189b9e629.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d0a9a367821e4915b1fa5998d1053cea.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d1de957b474548b59ea9bb538796bcde.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d222572a53b84710b703c1fc7e8a41a0.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d22fe9aecf6f47c5aeed6bb5f1f75929.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d2328756bebf43b09878c82e18435cdc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d2920bc2329543248cfce1b3a0157d5b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d2a354e5f33f4dd2923f2e82e7170af3.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d2e1333f02304bf29a7be0beb84fa718.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d3084577597c4b6183f4d7149aa4e398.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d342b260b77e49ee9a74fc3ac24b1c18.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d35b14473ea94c5fb34c80ef670e176f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d48bea3e3ccf49729f668e8561b889d7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d4ea83796f134ca9a31a1f61c54015da.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d527dee50bcd4f0d8b48ac3225942ada.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d586ebf34bad40ca996b8e460b87e488.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d5adcd3dfbde409a8dbd8f5ede1e5cc1.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d5fd8d41dd8341b483c0d32ebfd2e6cc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d606a5904948488aa3e6e5d6001043c8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d6562322cc254457a82bbb856fe3505c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d658f256ce3744978fc63715daa397b4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d661f3cf6f474763b6474043b0f0611e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d67e6b1e0e9a40cf8e38e83be329e23a.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d77d0dfcaf234674abda9b01a1d2a530.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d89736a035ce4f54b54cefe7e5b060ff.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d8a5b3263f3f4bb3a3c59973b892c2bf.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d9089561a0b64353b4227633dda06089.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d908eeb01f8d41198789dbbaad62d9cc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d95b2d34b84540b99dcf4a23b7373a98.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d9d3da8df8f941a9bd570266185f8ac6.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/d9ede10c130c43c1a96c4c8a27064d07.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/da4f73edd68d448bae58bc93a1f81bda.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/da78311f680347c69be3b27743188c12.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/daac36c348eb4a609150091354be75f8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dbccbf7347304f5eabc8e6847dfafdf7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dc13e32f27b24dfca63dafd470447ea2.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dc95516830b548aba4152e9ed13be42e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dc9a0440766f4855a83161e1c0e1484e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dcc2abd86bae4162bac4719d5f06efa4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dce5b05d1391403da4ae8cde655e4bb9.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dce6c139b09f4378b079e270e381c12c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dd201290c03c44f19c2ac0c895c50994.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dd93eac718724f6aa4a446dcff133f53.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/de09941abea14c64b5926f8cfc246a10.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/de557b2b0ae9429bb280d8539e124f8b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dec959d485724874b765074287ba9e16.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dece7e4d84ef479c9d9991efe8c3fbf3.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/df0fcb0b7605450495b55907468a7505.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/df13d9f05aae4a5b94cb89d501ecc5f8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/df231b287c1f47c9b6732199af7cdb11.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/df5560721a9b4c15b3a5c34e2692ee31.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/df98e3566462408bbbc1f6c89a74654b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/dfa09ab079054ad5bd1388925da693fc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e01983b56b83425694b177bc303c7890.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e061e9b27a6d4a3686b7d77ec073e6ca.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e063654b127f4c2e8fd71e4f9afdd299.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e074b8590e594a28b454bd102c4cd004.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e1639bdddab54807b80cce8065cc575d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e1a5cfd039c84903baaf427b374a7cec.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e1bbe8e4e6be4d0e926b6707f9cf0e51.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e1c6e853ee194ef7b2153649aae08037.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e224367492254057a05fe42c5826de13.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e245ab89d90d4f5b828c8f3c6e6236fe.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e283acd948b3427fb8df2ea2222bf643.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e2916545c99642df93c3018dfc015e9e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e2a5787e5715428ead36f84ca36f2241.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e38465547a4648afbe23ed2e01a6e023.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e3edde2a1b6545fda33e1ddfbc7ef13c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e40e460a6dca4c10a64fe4977aff8e91.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e41c37ae2a28404ca6e9f5bb4059092d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e45730c0d88b4673b494c3263903a640.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e50b19303546497ea651303cbf693dae.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e5c1c8ba9ec244a3a2212a7e9ead4380.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e5cddb35d77e4c7a8c2df8280c3a9936.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e72bdb497d9d4cacabc8a888dfbd0eaf.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e78a3febc21e4dd3aae1d00608372f62.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e7d60add903b4c41ae8cd35b611c1320.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e7dc8f8a285647ed9f0f4dc5fef47054.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e7eb6006c71f4429ae69dd54dc89f289.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e8421306236946f08be9f5ac6242a553.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e85265357bdf41ff97aa4c5e36561852.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e883c345306049b8b1c0288852121021.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e88b7fd9af984058b0ae4f5c42845d2a.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e8a0a84b8e4349eda6e3d08c7a03b33e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e97834007851443280d47e51a7abc8b6.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/e9de0e6220e24fecad70040a7bc5bbc4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ea4eeb7ae6574fefa84425754c82001f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ea5fc5868dbd4c9e844a1e61f65151cc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ea8b7be655234027869299b9941ccdab.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ea9a5d8fc7924a16b6d245960d87f19b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/eb10fc0ad2074cfaba8c1b0a9c0273e4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/eb43f220e62647e9899e19276907decc.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/eb6f464fdd704564808792f2b00f5e45.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ec534c885bf8493faee4b61a3e01388c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ec71036c78d949518a14943171c25768.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ed65b38ceef042f0a2e78e75f54d50ef.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/edca6ea89db743f4bf7e2875b554532d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/edd4343456fc44a9b2646bfc285852e2.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/edf05d9071d345ccb9788c259319fd5d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ee23d225c9b74dc58039ba8c609584f5.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ee2f37c04fad48ce97c729716cefabad.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ee35ed7dfcdc4842812b62a0c6e643e8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/eeb6458c8e5e4dd38678f50e89f44f3c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ef61998fb94940e78368a7e63c7aec81.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f0678ed61b6041e4b7351c7213970717.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f0ebcb8aaaca4a26a306e04966744509.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f11e6fd072a449c6a763a8f3cc0b81b9.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f11e757858634b82a93108767ee7fc10.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f136c0d4652240bf9896d7e93ab59f18.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f15716ebcb3b41dab90c28f14e1ee7d9.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f184ca6f115847ce96fbc25ef5643538.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f1954047f4ea467b979234bf1b794ab9.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f1c3ffdda0c14fa9a9a48902e56494ff.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f1f172e17db84bf6ae2d4bd8c4c0af3f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f2452bcd113343f3b1b8796ee43bfb2e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f25b7fb0067e48fea43726cedfbd1141.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f351f5d467594de88c895812fcf1c8bb.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f37462ed74fc4ef6a733903388075bba.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f37ac143b5b847cfbc4d6cb435a7224c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f3a58d129bc745b39cf1359f2674b4b7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f3b14bbcb99e4596a2133ee6dab88bfd.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f3e79e31e40e45398612a2c081347a4f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f3edb523b5504fae97ee9a12aa1d2043.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f47f4947984c44e0a0b74b10571b376b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f49852d9fb5743558f00e4576094d44d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f51257fd3d1140418ad3d52e9fa23cde.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f584f0034a37422689dd6aa39cb398d7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f58873f304da449497370f633793deb2.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f5c4863524484277a9daf766caabcb7b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f5d4e3574c744f2c8ecbadd1fe83259f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f5dee061f6864696a29e043d869b9cf8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f5ed36be62be4e70be5d81100340358b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f61bbdc409f8457780249f83a48e5799.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f690389754e34754a8f79e232d0e3ef4.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f69df7a8d11d4053b909f204422cd5be.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f6ccb46f33b94dfa9baf7d81089f05af.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f78082865eb94c91a22f2f8272a1178b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f79ef6c5cae84f3da2a1787a5bab74bb.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f7ee3250f1db4fba80f08b1ff98624d5.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f7f4239d5548401a88175ee27ce63bca.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f87b5af38115465cbc5ffe53aa3db59d.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f89cc456c904477784d72f4c8858ca69.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f8a63f4756cd4f2ca0d1b36ed74c59fb.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f8ac5e1322174c01a8625bcc7f851d10.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f8b3f9aa32d946afaa3a537c57752c27.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f8c781a92836426d9fc06da49540362c.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f93da0f639e54173be20835a5d258597.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f9492dba69cf496190add87db814e8d5.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/f99d82e6a52d4581ab6366b463b069b2.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fa4b5820da72462fa1636b6150c4657f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fa4e94f1377a40aba985ff142fd8e8c5.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fa63445da5a943fd9abf5ea92e0d6c46.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fa89a29389124eaeb4f97a8cea7a6aa1.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fa9d4400af3841cbbb00afb3f6b133f7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fab3c59fbca644b09cce6d13b6defe06.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fab5ee8b0988446c90f2fe767dcfc36e.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fb2df43fc2bb468abb3a07875d89d64f.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fb56974df9e14bff875fd4b81c7837db.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fb8ca04ba54c473b93a5c8283384bd73.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fbacf372322a4f4cbf9439c3198bf45b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fbfd381407454dca8cdffee5d93f7e73.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fc044ba9818746a78cd453ccb75eff13.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fc64ec0df65843d9b9e8381c6e9461b7.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fcc9a686a8ec4d5383312f6cea521827.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fd69c06c5055491abf729054f5eef638.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fd6d986aca7f44b1be18ac0962589d5b.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fd96bf7b56744ed4ae0c86506b634844.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fdba1155f6fd45519695060173a4f1fb.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fe59405a4a374fd5931fa23b5fd283e8.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fea7ef29309f4ddf8c82e531a99af6b0.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/feb7a3fd189747f7b08f57b0a72e0b51.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fed2c01ceba2476bbd5556cb4fc87a50.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fee99a85f9cb4dc59b464ae16dd82346.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/fef2795c5d0c406f8aa0bd5fa1c50e39.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ff04d147c028445588dd5895fa343341.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ff3379ec5df642b298f374c8ef645d26.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ffa4d05434a944aa964ec3f7abbcac05.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ffc5585c2dfc4df5888610e90bc09fb6.json
# data_aral/f337d126502344b582c0bbfaabc8b1f8/ffe1b76414ba47babd2636e328c43f33.json
#
# sent 147972 bytes  received 13709871 bytes  3959383.71 bytes/sec
# total size is 1176024649  speedup is 84.86
# Transferred: sent 165688, received 13722796 bytes, in 2.6 seconds
# Bytes per second: sent 63180.5, received 5232803.1

# %%
import datetime as dt, json

from pprint import pprint
from dataclasses import dataclass
from typing import Optional

@dataclass
class Query:

    user            : str
    prefix          : str
    suffix          : str
    trigger         : str
    language        : str
    ide             : str
    version         : str
    store           : bool
    timestamp       : dt.datetime
    predictions     : dict
    predict_time    : float
    survey          : bool

    time_since_last_completion: float
    filter_type     : str
    filter_time     : float
    should_filter   : bool
    study_version   : str

    @classmethod 
    def from_dict(cls, data: dict) -> 'Query':
        ''' Parse json dict into pythonic types, returning Query or VerifiedQuery '''

        try: 
            data['timestamp'] = dt.datetime.fromisoformat(data['timestamp'])
            return VerifiedQuery.from_dict(data) \
                if 'verifyToken' in data else cls(**data)
        except Exception as e:
            print(f'Error parsing query: {e}')
            pprint(data)

@dataclass 
class VerifiedQuery(Query):
    verify_token    : str
    chosen_model    : str
    ground_truth    : str
    shown_times     : Optional[list[dt.datetime]]
    accept_time     : dt.datetime

    @classmethod
    def from_dict(cls, data: dict):
        ''' parse json dict into pythonic types '''

        data['verify_token'] = data.pop('verifyToken')
        data['accept_time'] = dt.datetime.fromisoformat(data['accept_time'])
        
        # pushed bugfix for shown_times field on client-side
        data['shown_times'] = [dt.datetime.fromisoformat(t) for t in data['shown_times']] \
            if 'shown_times' in data else None

        return cls(**data)

# %%
unfiltered_queries_per_user = {
    user: sorted([
        Query.from_dict({
            **json.load(open(os.path.join(DATA_DIR, user, query))),
            'user': user
        }) for query in os.listdir(os.path.join(DATA_DIR, user))
    ], key=lambda q: q.timestamp, reverse=True) 
    for user in os.listdir(DATA_DIR) if user != '.DS_Store'
}

# %%
oops_date = dt.datetime(2024, 3, 21, 17, 17, 50)
queries_per_user = {
    user: [q for q in queries if q.timestamp >= oops_date] \
    for user, queries in unfiltered_queries_per_user.items()
}
oops_queries = [q for q in sum(unfiltered_queries_per_user.values(), []) if q.timestamp < oops_date]
len(oops_queries), len(sum(queries_per_user.values(), []))
# Out:
# (15047, 71592)

# %% [markdown]
# #### Recovering Logs
# I accidentally forgot to save filtered-out queries in the first 24 hours of the user study; which corresponds to about 9253 data points. Luckily I have a log file, which i pre-process with the following pipeline:
#
# ```sh
# cat two_clean.log | grep -v 'POST' | sed 's/-1  | //g' | sed '/^Traceback/,/^RuntimeError/d' | awk '/^\[2024/ {if (NR>1) print ""; print} !/^\[2024/ {printf " %s", $0}' > two_cleaner.log
# ```

# %%
import tqdm 
with open('notebooks/paper/two_cleaner.log', 'r') as f: 
    logs = f.readlines()

# if the line does not start with [2024, append it to the previous line
clean_logs = [] 
for line in logs: 
    if line.startswith('['): 
        clean_logs.append(line)
    else: 
        clean_logs[-1] += line

# remove 'WARNING in api: ' from each line 
clean_logs = [line.replace('WARNING in api: ', '') for line in clean_logs]

# remove any lines that contain 'Error' 
clean_logs = [line for line in clean_logs if 'Error' not in line]

recovered_queries = [] 
fixed_kwargs = dict(user='rec', prefix='', suffix='', trigger='', language='', ide='', version='', store=False, 
                    predictions=dict(), predict_time=0.0, survey=False, time_since_last_completion=0.0,
                    filter_time=0.0, study_version='')

for line in tqdm.tqdm(clean_logs): 
    for filter_type in ['no_filter', 'feature', 'context', 'joint_a', 'joint_h']: 
        if filter_type in line: 

            filter_type = filter_type
            timestamp = dt.datetime.fromisoformat(line[1:24].replace(' ', 'T'))
            should_filter = 'filter' in line[:34]

            query = Query(**fixed_kwargs, timestamp=timestamp, filter_type=filter_type, should_filter=should_filter)
            recovered_queries.append(query)
            break

print(f'Recovered {len(recovered_queries)} queries')
# Out:
# 100%|██████████| 9115/9115 [00:00<00:00, 481900.33it/s]
# Recovered 9112 queries

# %%
# So, recovered_queries contains both the filtered and unfiltered queries. (9'112 from the last log)
# while, oops_queries contains only the unfiltered queries. (14'047 including but also before the last log)
# to maintain the same data distribution, we need to merge them. 

# NOTE: oops queries contains 18 filtered queries (one for each user) which are overriden each time
# let's filter those out first to avoid duplicates. 

unfiltered_queries = [q for q in oops_queries if not q.should_filter]

# NOTE: oops_queries starts much before recovered_queries. 
unfiltered_queries = sorted(unfiltered_queries, key=lambda q: q.timestamp)
recovered_queries = sorted(recovered_queries, key=lambda q: q.timestamp)

print(f'first oops query: {unfiltered_queries[0].timestamp}')
print(f'first recovered query: {recovered_queries[0].timestamp}')

# modify timestamp as the os time on larisa is not set correctly 
filter_timestamp = recovered_queries[0].timestamp + dt.timedelta(minutes=26)

# So, let's remove the oops_queries with timestamp < first recovered query timestamp
unfiltered_queries = [q for q in unfiltered_queries if q.timestamp >= filter_timestamp]

n_oops_filtered = len([q for q in unfiltered_queries if q.should_filter])
n_oops_unfiltered = len([q for q in unfiltered_queries if not q.should_filter])
print(f'Maintained {len(unfiltered_queries)} oops queries ({n_oops_filtered} filtered, {n_oops_unfiltered} unfiltered)')
n_rec_filtered = len([q for q in recovered_queries if q.should_filter])
n_rec_unfiltered = len([q for q in recovered_queries if not q.should_filter])
print(f'Merging with {len(recovered_queries)} recovered queries ({n_rec_filtered} filtered, {n_rec_unfiltered} unfiltered)')

# add the filtered recovered queires to the oops_queries
unfiltered_queries += [q for q in recovered_queries if q.should_filter]

print(f'Final count: {len(unfiltered_queries)} queries') # off by ~4/9000 but good enough
# Out:
# first oops query: 2024-03-17 15:48:44.953718
# first recovered query: 2024-03-20 09:43:43.963000
# Maintained 6744 oops queries (0 filtered, 6744 unfiltered)
# Merging with 9112 recovered queries (2372 filtered, 6740 unfiltered)
# Final count: 9116 queries

# %%
n_users = set(q.user for q in unfiltered_queries)
print(f'Found {len(n_users)-1} users (excl the recovered one which we cannot match )')

# add unfiltred queries to the queries_per_user dict
for query in unfiltered_queries: 
    if query.user not in queries_per_user: 
        queries_per_user[query.user] = []
    queries_per_user[query.user].append(query)
# Out:
# Found 12 users (excl the recovered one which we cannot match )

# %%
# exclude queries where ground-truth is empty 
# exclude queries where the predictions are empty
n_empty = 0
for user, queries in queries_per_user.items(): 
    n_empty += len([q for q in queries if not q.predictions or len(q.predictions) == 0])
print(f'{n_empty} queries have empty predictions')

queries_per_user = {
    user: [q for q in queries if 
        #    q.ground_truth and 
           len(q.predictions) > 0
        ]
    for user, queries in queries_per_user.items()
}
# Out:
# 23376 queries have empty predictions

# %% [markdown]
# #### Computing Stats

# %%
n_queries = sum(len(queries) for queries in queries_per_user.values())
n_users = len(queries_per_user)
n_verified = len(verified := \
                [q for queries in queries_per_user.values() 
                for q in queries if isinstance(q, VerifiedQuery)]
            )
n_filtered = len(filtered := \
                 [q for queries in queries_per_user.values()
                 for q in queries if q.should_filter])

all_queries = sum(queries_per_user.values(), [])
queries_per_filter = {} 
for query in all_queries: 
    filter_type = query.filter_type
    if filter_type not in queries_per_filter: 
        queries_per_filter[filter_type] = [query]
    else: 
        queries_per_filter[filter_type].append(query)

# create a sorted_dict based on the keys 
queries_per_filter = dict(sorted(queries_per_filter.items(), key=lambda x: x[0]))

def tab(list_to_tabulate: list) -> str:
    return "\t".join([f'{i:<15}' if isinstance(i, str) else f'{i:<15.1f}' for i in list_to_tabulate])

def perc(list_1, list_2) -> list:
    return [f'{v:<5} \033[37m({(100*v/n) if n > 0 else 0 :.2f}%)\033[0m' for v, n in zip(list_1, list_2)]

queries_per_filter = dict(sorted(queries_per_filter.items(), key=lambda x: x[0]))

filters = tab(queries_per_filter.keys())
n_per_filter = [len(v) for v in queries_per_filter.values()]
f_per_filter = [len([q for q in v if q.should_filter == True]) for v in queries_per_filter.values()]
i_per_filter = [len([q for q in v if not q.should_filter]) for v in queries_per_filter.values()]
v_per_filter = [len([q for q in v if isinstance(q, VerifiedQuery)]) for v in queries_per_filter.values()]

# NOTE: Filtering out any queries with <10 chars
not_pre_filter_per_filter = [len([q for q in v if (len(q.prefix) + len(q.suffix)) < 10]) for v in queries_per_filter.values()]
pre_filter_per_filter = [len([q for q in v if (len(q.prefix) + len(q.suffix)) >= 10]) for v in queries_per_filter.values()]
passed_per_filter = [len([q for q in v_2 if not q.should_filter or q.trigger == 'manual']) for v_2 in \
                     [[q for q in v if (len(q.prefix) + len(q.suffix)) >= 10] for v in queries_per_filter.values()]]
perceived_v_per_filter = perc([len([q for q in v if isinstance(q, VerifiedQuery)]) for v in queries_per_filter.values()], passed_per_filter)

man_per_filter  = [len([q for q in v if q.trigger == 'manual']) for v in queries_per_filter.values()]
idle_per_filter = [len([q for q in v if q.trigger == 'idle']) for v in queries_per_filter.values()]
auto_per_filter = [len([q for q in v if q.trigger == 'auto']) for v in queries_per_filter.values()]

man_filtered_out = [len([q for q in v if q.trigger == 'manual' and q.should_filter]) for v in queries_per_filter.values()]
idle_filtered_out = [len([q for q in v if q.trigger == 'idle' and q.should_filter]) for v in queries_per_filter.values()]
auto_filtered_out = [len([q for q in v if q.trigger == 'auto' and q.should_filter]) for v in queries_per_filter.values()]

avg_filter_time = [sum([q.filter_time for q in v]) / len(v) for v in queries_per_filter.values()]
med_filter_time = [sorted([q.filter_time for q in v])[len(v)//2] for v in queries_per_filter.values()]
std_filter_time = [pd.Series([q.filter_time for q in v]).std() for v in queries_per_filter.values()]

# compute the 2.5th and 97.5th percentile for the filter time
low_filter_time = [sorted([q.filter_time for q in v])[int(0.05*len(v))] for v in queries_per_filter.values()]
high_filter_time = [sorted([q.filter_time for q in v])[int(0.95*len(v))] for v in queries_per_filter.values()]
 
# get the last query's timestamp per filter 
last_query_per_filter = {k: max(v, key=lambda q: q.timestamp) for k, v in queries_per_filter.items()}
# compute timedelta compared to now
time_since_last_query = {k: dt.datetime.now() - v.timestamp - dt.timedelta(hours=1) \
                         for k, v in last_query_per_filter.items()}
# convert to nice string repr with h:m but no s
time_since_last_query = {k: str(time_since_last_query[k]).split('.')[0] for k in time_since_last_query}
time_per_filter = [time_since_last_query[k] for k in queries_per_filter.keys()]
# remove the seconds from the time_since_last_query
# time_per_filter = [':'.join(t.split(':')[:2]) for t in time_per_filter]
time_per_filter = [f'{t} ago' for t in time_per_filter]

acc_rate_per_filter = [100*v/i if i > 0 else 0 for v, i in zip(v_per_filter, i_per_filter)]
rel_acc_per_filter = [f'{100*acc_rate / acc_rate_per_filter[-1]:.1f}%' for acc_rate in acc_rate_per_filter]

shown_suggestion_lengths = [[sum(len(prediction) for prediction in q.predictions.values()) / len(q.predictions)\
                                for q in queries if q.predictions and len(q.predictions) > 0] \
                                    for queries in queries_per_filter.values()]
med_suggestion_lengths = [sorted(lengths)[len(lengths)//2] for lengths in shown_suggestion_lengths]
avg_suggestion_lengths = [sum(lengths) / len(lengths) for lengths in shown_suggestion_lengths]

acc_suggestion_lengths = [[sum(len(prediction) for prediction in q.predictions.values()) / len(q.predictions)\
                                for q in queries if isinstance(q, VerifiedQuery) and len(q.predictions) > 0] \
                                    for queries in queries_per_filter.values()]
med_acc_suggestion_lengths = [sorted(lengths)[len(lengths)//2] for lengths in acc_suggestion_lengths]
avg_acc_suggestion_lengths = [sum(lengths) / len(lengths) for lengths in acc_suggestion_lengths]

print(f'''
    {n_queries} completions for {n_users} users  ({n_filtered} filtered out in total)
    {n_verified} accepted in total ({100*n_verified/n_queries:.2f}%)

    Filter            | \033[1m{filters} \033[0m
    queries           | {tab(n_per_filter)}
    last query        | {tab(time_per_filter)}

    filtered out      | {tab(perc(f_per_filter, n_per_filter))}
    kept              | {tab(perc(i_per_filter, n_per_filter))}

    avg. filter time  | {tab([f'{t:.2f}' for t in avg_filter_time])}
    med. filter time  | {tab([f'{t:.2f}' for t in med_filter_time])}
    ± std.            | {tab([f'{t:.2f}' for t in std_filter_time])}
    5th perc.         | {tab([f'{t:.2f}' for t in low_filter_time])}
    95th perc.        | {tab([f'{t:.2f}' for t in high_filter_time])}

    accs              | {tab(perc(v_per_filter, n_per_filter))}
    perc. accs        | {tab(perc(v_per_filter, i_per_filter))}
    rel. to no_filter | {tab(rel_acc_per_filter)}

    avg. shown length | {tab(avg_suggestion_lengths)}
    med. shown length | {tab(med_suggestion_lengths)}

    avg. acc. length  | {tab(avg_acc_suggestion_lengths)}
    med. acc. length  | {tab(med_acc_suggestion_lengths)}

    man               | {tab(perc(man_per_filter, n_per_filter))}
    ''')
# Out:
#     57332 completions for 45 users  (10 filtered out in total)
#     726 accepted in total (1.27%)
#
#     Filter            | context        	feature        	joint_a        	joint_h        	no_filter
#     queries           | 14056.0        	7804.0         	8652.0         	11683.0        	15137.0
#     last query        | 10:09:11 ago   	3:00:58 ago    	2:03:04 ago    	10:07:13 ago   	1:00:28 ago
#
#     filtered out      | 8     (0.06%)	0     (0.00%)	1     (0.01%)	1     (0.01%)	0     (0.00%)
#     kept              | 14048 (99.94%)	7804  (100.00%)	8651  (99.99%)	11682 (99.99%)	15137 (100.00%)
#
#     avg. filter time  | 32.14          	0.19           	35.31          	35.36          	0.02
#     med. filter time  | 23.64          	0.16           	24.42          	18.56          	0.02
#     ± std.            | 27.86          	0.07           	30.23          	41.42          	0.01
#     5th perc.         | 11.21          	0.13           	11.89          	11.30          	0.01
#     95th perc.        | 75.10          	0.32           	89.49          	106.55         	0.02
#
#     accs              | 179   (1.27%)	53    (0.68%)	86    (0.99%)	184   (1.57%)	224   (1.48%)
#     perc. accs        | 179   (1.27%)	53    (0.68%)	86    (0.99%)	184   (1.58%)	224   (1.48%)
#     rel. to no_filter | 86.1%          	45.9%          	67.2%          	106.4%         	100.0%
#
#     avg. shown length | 28.0           	26.1           	28.5           	23.1           	23.3
#     med. shown length | 18.3           	16.7           	17.3           	14.7           	13.0
#
#     avg. acc. length  | 20.6           	16.2           	20.2           	16.6           	21.9
#     med. acc. length  | 12.7           	12.0           	13.3           	10.7           	15.3
#
#     man               | 17    (0.12%)	0     (0.00%)	1     (0.01%)	6     (0.05%)	32    (0.21%)

# %%
#     < 10chr           | {tab(perc(not_pre_filter_per_filter, n_per_filter))}
#     >= 10chr          | {tab(perc(pre_filter_per_filter, n_per_filter))}
#     passed            | {tab(perc(passed_per_filter, pre_filter_per_filter))}
#     perceived accs    | {tab(perceived_v_per_filter)}
# 
#     auto              | {tab(perc(auto_per_filter, n_per_filter))}
#     idle              | {tab(perc(idle_per_filter, n_per_filter))}
# 
#     n man filtered    | {tab(perc(man_filtered_out, man_per_filter))}
#     n auto filtered   | {tab(perc(auto_filtered_out, auto_per_filter))}
#     n idle filtered   | {tab(perc(idle_filtered_out, idle_per_filter))}

# %%
stats = {} 
# print three most recent users, and the number of queries in the last 24 hours 
# for user, queries in sorted({k: v for k, v in queries_per_user.items() if len(v) > 0}, key=lambda x: len(x[1])):
for user, queries in sorted(queries_per_user.items(), key=lambda x: len(x[1]), reverse=True):
                            # key=lambda x: x[1][0].timestamp, reverse=True):
    most_recent = (str(dt.datetime.now() - dt.timedelta(hours=1) - queries[0].timestamp).split('.')[0] )\
          if len(queries) > 0 else None
    user_uuid = user[:4]
    vqs = [q for q in queries if isinstance(q, VerifiedQuery)]
    last_day_qs = [q for q in queries if q.timestamp > dt.datetime.now() - dt.timedelta(days=1)]
    last_day_vqs = [q for q in last_day_qs if isinstance(q, VerifiedQuery)]
    last_day_acc_rate = len(last_day_vqs) / len(last_day_qs) if last_day_qs else 0
    last_day_top_three_langs = sorted(
        {q.language for q in queries if q.timestamp > dt.datetime.now() - dt.timedelta(days=1)},
        key=lambda lang: len([q for q in queries if q.language == lang]),
        reverse=True
    )[:3]
    top_langs = sorted(
        {q.language for q in queries},
        key=lambda lang: len([q for q in queries if q.language == lang]),
        reverse = True
    )

    stats[user_uuid] = {
        ('','most recent'): most_recent,
        ('total', 'n'): len(queries),
        ('total', 'acc'): len(vqs),
        ('total', 'acc_rate'): (100*len(vqs) / len(queries)) if len(queries) > 0 else 0,
        ('total', 'top langs'): top_langs,
        ('last day', 'n'): len(last_day_qs),
        ('last day', 'acc'): len(last_day_vqs),
        ('last day', 'rate'): 100*last_day_acc_rate,
        ('last day', 'top langs'): last_day_top_three_langs
    }

# %%
# convert tuples to layered headings in dataframe
df = pd.DataFrame(stats).T
df.columns = pd.MultiIndex.from_tuples(df.columns)
df.sort_values(('', 'most recent'), ascending=False)

# print n users with >50 queries 
n_with_50 = len([q for q in queries_per_user.values() if len(q) >= 50])
print(f'\t{n_with_50} users with 50 or more queries')

df
# Out:
# 	34 users with 50 or more queries
#                          total                 \
#             most recent      n  acc  acc_rate
# 1ae4    3 days, 8:11:53  13876   23  0.165754
# 8cc7    3 days, 8:56:56  12736   51   0.40044
# a926            6:31:38   7706   88  1.141967
# ed93   2 days, 15:09:49   6252    6  0.095969
# 5747           18:11:36   5410   87  1.608133
# f337            6:24:25   4342   33  0.760018
# 7f5d            7:02:05   3345  129  3.856502
# 0787           21:56:16   2540   15  0.590551
# a420            6:26:30   2419   28  1.157503
# rec    15 days, 8:49:18   2372    0       0.0
# cc39    5 days, 7:21:11   2165   49  2.263279
# f47e    3 days, 1:35:25   2013   11  0.546448
# 6064   12 days, 3:03:23   1145    7  0.611354
# 2f6a    8 days, 5:06:00   1048   16  1.526718
# c9b7    8 days, 8:07:27    841   10  1.189061
# 04db   3 days, 20:33:08    816   11  1.348039
# c715   12 days, 1:37:06    711    3  0.421941
# 0178   5 days, 13:30:42    585    9  1.538462
# 250b     1 day, 2:02:22    570    5  0.877193
# 7cf7   4 days, 18:08:36    401    7  1.745636
# df7d           23:53:21    346    4  1.156069
# 8c9f    9 days, 7:47:55    314    2  0.636943
# 7dd3   11 days, 3:51:48    308    7  2.272727
# 62a9    3 days, 4:33:14    301    9  2.990033
# e575   6 days, 21:09:05    268    1  0.373134
# 8caf            6:24:35    209    2  0.956938
# 6832     1 day, 3:30:30    189    1  0.529101
# ebdc   12 days, 2:44:24    145    6  4.137931
# 53ed            9:06:29    134    2  1.492537
# 1c67    4 days, 5:58:58    123    2  1.626016
# cff8    1 day, 16:55:28     70    0       0.0
# 4849   7 days, 10:06:33     70    0       0.0
# 49ee    1 day, 23:12:26     56    2  3.571429
# c961  13 days, 11:26:00     53    2  3.773585
# 90b0    5 days, 8:57:07     46    0       0.0
# a57c   8 days, 11:48:39     23    0       0.0
# b509   5 days, 23:33:15     21    0       0.0
# 8166   13 days, 8:48:09      9    0       0.0
# f1d4   3 days, 19:54:51      3    0       0.0
# cbe6   14 days, 0:09:31      2    0       0.0
# 5d8f  11 days, 17:57:54      2    0       0.0
# 7869    6 days, 3:03:20      1    0       0.0
# cbb6               None      0    0         0
# 3a63               None      0    0         0
# 4217               None      0    0         0
#
#                                                         last day      \
#                                               top langs        n acc
# 1ae4                          [latex, scminput, python]        0   0
# 8cc7  [python, latex, markdown, typescript, plaintex...        0   0
# a926  [python, yaml, ignore, latex, jsonc, propertie...      401   5
# ed93                          [latex, python, scminput]        0   0
# 5747  [python, typescriptreact, typescript, plaintex...      644   1
# f337  [python, http, markdown, csv, dynamic csv, pip...      382   2
# 7f5d    [php, html, css, cpp, python, pip-requirements]        2   0
# 0787  [typescript, lua, scss, typescriptreact, prope...      120   1
# a420      [python, markdown, java, search-result, json]      350   3
# rec                                                  []        0   0
# cc39                                 [html, javascript]        0   0
# f47e  [css, html, python, javascript, markdown, json...        0   0
# 6064                                 [python, markdown]        0   0
# 2f6a                       [markdown, python, cpp, ini]        0   0
# c9b7                       [python, markdown, scminput]        0   0
# 04db  [javascript, json, scminput, markdown, html, p...        0   0
# c715           [typescriptreact, typescript, css, json]        0   0
# 0178  [typescriptreact, yaml, json, typescript, pyth...        0   0
# 250b            [python, jsonc, shellscript, yaml, log]        0   0
# 7cf7                           [python, arduino-output]        0   0
# df7d                     [python, scminput, yaml, json]        0   0
# 8c9f                                           [python]        0   0
# 7dd3                                           [python]        0   0
# 62a9  [python, javascriptreact, typescript, json, pl...        0   0
# e575                  [latex, bibtex, markdown, python]        0   0
# 8caf  [python, javascript, properties, javascriptrea...       45   0
# 6832                                           [python]        0   0
# ebdc                                           [python]        0   0
# 53ed                       [java, http, json, markdown]        1   0
# 1c67                                           [python]        0   0
# cff8        [python, code-runner-output, go, plaintext]        0   0
# 4849                                      [ini, python]        0   0
# 49ee                                             [java]        0   0
# c961                                       [javascript]        0   0
# 90b0                                [latex, jsonc, log]        0   0
# a57c                    [html, javascript, css, python]        0   0
# b509                                 [python, markdown]        0   0
# 8166                                           [python]        0   0
# f1d4                                           [python]        0   0
# cbe6                                        [php, html]        0   0
# 5d8f                                       [javascript]        0   0
# 7869                                           [python]        0   0
# cbb6                                                 []        0   0
# 3a63                                                 []        0   0
# 4217                                                 []        0   0
#
#
#           rate                            top langs
# 1ae4         0                                   []
# 8cc7         0                                   []
# a926  1.246883               [python, yaml, ignore]
# ed93         0                                   []
# 5747   0.15528  [typescriptreact, plaintext, jsonc]
# f337   0.52356        [python, http, dockercompose]
# 7f5d       0.0                                [css]
# 0787  0.833333                 [typescript, sqlite]
# a420  0.857143             [python, markdown, json]
# rec          0                                   []
# cc39         0                                   []
# f47e         0                                   []
# 6064         0                                   []
# 2f6a         0                                   []
# c9b7         0                                   []
# 04db         0                                   []
# c715         0                                   []
# 0178         0                                   []
# 250b         0                                   []
# 7cf7         0                                   []
# df7d         0                                   []
# 8c9f         0                                   []
# 7dd3         0                                   []
# 62a9         0                                   []
# e575         0                                   []
# 8caf       0.0         [javascript, css, plaintext]
# 6832         0                                   []
# ebdc         0                                   []
# 53ed       0.0                               [json]
# 1c67         0                                   []
# cff8         0                                   []
# 4849         0                                   []
# 49ee         0                                   []
# c961         0                                   []
# 90b0         0                                   []
# a57c         0                                   []
# b509         0                                   []
# 8166         0                                   []
# f1d4         0                                   []
# cbe6         0                                   []
# 5d8f         0                                   []
# 7869         0                                   []
# cbb6         0                                   []
# 3a63         0                                   []
# 4217         0                                   []
